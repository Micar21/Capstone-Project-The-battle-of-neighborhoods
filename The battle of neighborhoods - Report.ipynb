# %% [markdown]
# # Importance of the hospitality industry in Barcelona and Madrid - Report

# %% [markdown]
# #### By Michael Chipantasi

# %% [markdown]
# ## 1. Introduction: Business Problem

# %% [markdown]
# ### 1.1. Background

# %% [markdown]
# It is a fact that **Hospitality** has a big impact on countries's economies, specially in develop countries where people could have access to restaurants from five Michellin Stars to bars or cafes.
#
# Also, it is knowing that mediterranean cuisine has an enormous popularity everywhere. It has been one of the most influence culinary culture and it has been named one of the healthies diets.
#
# On the other hand,**Spanish cuisine** has developed in the last 20 years considerably. Spanish restaurant as *Celler de Can Roca* has been named *The Best Restaurant in the World* twice, in 2013 and 2018. Moreover, in the last 20 years a hundreds of Spanish chefs had been on top of their ranking and their names have been recognized around the world as exemple: Joan Roca, Martin Berasategui, Daviz Muñoz, Jordi Cruz among other great chefs.
#
# In the last year, the world has suffered a huge pandemia, **COVID-19**, that has changed everything. Hospitality, big/small restaurants, cafes, winer bar and others, has been impacted negatively for the different restrictions that the differents governments has taken to reduce the pandemic impact in their countries. These measures affected to everybody's economies in different ways. For this reason, it is important to know how it has influenced in our lives.

# %% [markdown]
# ### 1.2. Problem

# %% [markdown]
# In this project we will try to identify how important is Hospitality (restaurants) in the economy of the two of the most important cities of Spain, **Madrid** and **Barcelona**.
#
# To know the importance of Hospitality in each city, we need to determinate how many restaurants are based in each city. Once we have the total number of restaurants, we will define which are the top five kind of restaurant/food that predominate in both Madrid and Barcelona.
#
# Finally, we will try to find which district has more restaurants for each city and compare where they are located to determinate the distribution of the leisure in Madrid and Barcelona.
#
# Following these steps would help to understand which city had been **more affected** by the lockdown that the Spanish Goverment has imposed as an action to reduce the level of inflection due to COVID-19 that it is been produced in Barcelona and Madrid in the past year.

# %% [markdown]
# ## 2. Data

# %% [markdown]
# ### 2.1. Data source

# %% [markdown]
# To solve our problem, we will use the following data:
#
#  - total number of restaurants
#  - classified restaurant by kind of food
#  - located restaurant by districts
#
# We need to find the above data for both Barcelona and Madrid.
#
# a. The **total number of restaurants** will be us an idea of how important is Hospitality in the economy of the city.
#
# b. If we can **classify restaurants** by the kind of food, it will give us some idees of how different are the customs of the citizens of each city.
#
# c. By **locatting the restaurant by districts**, it could help us to determinate where people have more chances to find a place to have a meal.
#
# Also, we will need to use the next sources to extract the information required to solve this project:
#
#  - Foursquere API --> number of restaurants
#  - Google Maps API reverse geocoding --> location of the cities
#  - Google Maps API geocoding --> location of the restaurants
#  - Wikipedia --> district of the cities

# %% [markdown]
# To sum up, the sources that will be use to develop this project are the following:

# %%
import numpy as np

import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json
import requests
import urllib.request
import random
from pandas.io.json import json_normalize

import matplotlib.cm as cm
import matplotlib.colors as colors

from sklearn.cluster import KMeans
from bs4 import BeautifulSoup

# %%
# !conda install -c conda-forge geopy --yes
from geopy.geocoders import Nominatim
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: |
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/noarch::ibm-wsrt-py37main-main==custom=1937
#   - conda-forge/linux-64::pytorch==1.8.0=cpu_py37hafa7651_0
#   - defaults/noarch::ibm-wsrt-py37main-keep==0.0.0=1937
# done
#
# # All requested packages already installed.

# %%
# !conda install -c conda-forge folium=0.5.0 --yes
import folium
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: -
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/noarch::ibm-wsrt-py37main-main==custom=1937
#   - conda-forge/linux-64::pytorch==1.8.0=cpu_py37hafa7651_0
#   - defaults/noarch::ibm-wsrt-py37main-keep==0.0.0=1937
# done
#
# # All requested packages already installed.

# %% [markdown]
# ### 2.2. Data cleaning

# %% [markdown]
# To start with this project, it has been used **Wikipedia** to collect a **list of the different districts** for both Barcelona and Madrid using BeautifulSoup.
# Once the data was available, it was transformed to Pandas DataFrame to have an easy way develop the different actions during the project.

# %% [markdown]
# * **BARCELONA**

# %%
url = "https://es.wikipedia.org/wiki/Distritos_de_Barcelona"
page = urllib.request.urlopen(url)
soup = BeautifulSoup(page, "lxml")

# %%
all_tables = soup.find_all("table")
right_table = soup.find_all('table', class_='wikitable')

# %%
column_names = ['Number','District','Location','Size (km2)','Population','Density','Neighborhoods','Council']
bcn = pd.DataFrame(columns =column_names)

# %%
for tr_cell in right_table[0].find_all('tr'):
    row_data = []
    for td_cell in tr_cell.find_all('td'):
        row_data.append(td_cell.text.strip())
    if len(row_data)==8:
        bcn.loc[len(bcn)] = row_data

# %%
bcn
# Out:
#   Number             District Location Size (km2) Population    Density  \
# 0      1         Ciutat Vella                4,11    103 429  25 159,09
# 1      2             Eixample                7,46    265 910  35 625,67
# 2      3       Sants-Montjuïc               22,68    184 091    8118,32
# 3      4            Les Corts                6,02     81 974  13 607,11
# 4      5  Sarrià-Sant Gervasi               19,91    149 260    7497,11
# 5      6               Gràcia                4,19    121 798  29 082,62
# 6      7     Horta - Guinardó               11,96    171 495  14 342,64
# 7      8           Nou Barris                8,05    170 669  21 198,48
# 8      9          Sant Andreu                6,59    149 821  22 724,25
# 9     10           Sant Martí               10,39    238 315  22 943,58
#
#                                        Neighborhoods  \
# 0  El Raval (1), Barrio Gótico (2), La Barcelonet...
# 1  El Fort Pienc (5), Sagrada Familia (6), Dreta ...
# 2  Poble Sec (11), La Marina del Prat Vermell (12...
# 3  Les Corts (19), La Maternitat i Sant Ramon  (2...
# 4  Vallvidrera, el Tibidabo i les Planes (22), Sa...
# 5  Vallcarca i els Penitents (28), El Coll (29), ...
# 6  Baix Guinardó (33), Can Baró (34), El Guinardó...
# 7  Vilapicina i La Torre Llobeta (44), Porta (45)...
# 8  La Trinitat Vella (57), Baró de Viver (58), El...
# 9  El Camp de l'Arpa del Clot (64), El Clot (65),...
#
#                                              Council
# 0     Jordi Rabassa              (Barcelona en Comú)
# 1  Jordi Martí                   (Barcelona en Comú)
# 2    Marc Serra                  (Barcelona en Comú)
# 3                                 Xavier Marcé (PSC)
# 4                               Albert Batlle  (PSC)
# 5                    Eloi Badia  (Barcelona en Comú)
# 6                                 Rosa Alarcón (PSC)
# 7                       Marga Marí-Klose       (PSC)
# 8    Lucía Martín                (Barcelona en Comú)
# 9                                 David Escudé (PSC)

# %% [markdown]
# * **MADRID**

# %%
url_2 = "https://en.wikipedia.org/wiki/Districts_of_Madrid"
page_2 = urllib.request.urlopen(url_2)
soup_2 = BeautifulSoup(page_2, "lxml")

# %%
all_tables_2 = soup_2.find_all("table")
right_table_2 = soup_2.find_all('table', class_='wikitable sortable')

# %%
column_names_2 = ['Number','District','Size (ha)','Population','Density','Location','Neighborhoods']
mad = pd.DataFrame(columns =column_names_2)

# %%
for tr_cell in right_table_2[0].find_all('tr'):
    row_data = []
    for td_cell in tr_cell.find_all('td'):
        row_data.append(td_cell.text.strip())
    if len(row_data)==7:
        mad.loc[len(mad)] = row_data

# %%
mad
# Out:
#    Number             District  Size (ha) Population Density Location  \
# 0       1               Centro     522.82    131,928  252.34
# 1       2           Arganzuela     646.22    151,965  235.16
# 2       3               Retiro     546.62    118,516  216.82
# 3       4            Salamanca     539.24    143,800  266.67
# 4       5            Chamartín     917.55    143,424  156.31
# 5       6               Tetuán     537.47    153,789  286.13
# 6       7             Chamberí     467.92    137,401  293.64
# 7       8  Fuencarral-El Pardo  23,783.84    238,756   10.04
# 8       9      Moncloa-Aravaca   4,653.11    116,903   25.12
# 9      10               Latina   2,542.72    233,808   91.95
# 10     11          Carabanchel   1,404.83    243,998  173.68
# 11     12                Usera     777.77    134,791  173.30
# 12     13   Puente de Vallecas   1,496.86    227,595  152.05
# 13     14            Moratalaz     610.32     94,197  154.34
# 14     15        Ciudad Lineal   1,142.57    212,529  186.01
# 15     16            Hortaleza   2,741.98    180,462   65.81
# 16     17           Villaverde   2,018.76    142,608   70.64
# 17     18    Villa de Vallecas   5,146.72    104,421   19.86
# 18     19            Vicálvaro   3,526.67     70,051   19.86
# 19     20  San Blas-Canillejas   2,229.24    154,357   69.24
# 20     21              Barajas   4,192.28     46,876   11.18
#
#                                         Neighborhoods
# 0   Palacio (11)Embajadores (12)Cortes (13)Justici...
# 1   Imperial (21)Acacias (22)Chopera (23)Legazpi (...
# 2   Pacífico (31)Adelfas (32)Estrella (33)Ibiza (3...
# 3   Recoletos (41)Goya (42)Fuente del Berro (43)Gu...
# 4   El Viso (51)Prosperidad (52)Ciudad Jardín (53)...
# 5   Bellas Vistas (61)Cuatro Caminos (62)Castillej...
# 6   Gaztambide (71)Arapiles (72)Trafalgar (73)Alma...
# 7   El Pardo (81)Fuentelarreina (82)Peñagrande (83...
# 8   Casa de Campo (91)Argüelles (92)Ciudad Univers...
# 9   Los Cármenes (101)Puerta del Ángel (102)Lucero...
# 10  Comillas (111)Opañel (112)San Isidro (113)Vist...
# 11  Orcasitas (121)Orcasur (122)San Fermín (123)Al...
# 12  Entrevías (131)San Diego (132)Palomeras Bajas ...
# 13  Pavones (141)Horcajo (142)Marroquina (143)Medi...
# 14  Ventas (151)Pueblo Nuevo (152)Quintana (153)Co...
# 15  Palomas (161)Piovera (162)Canillas (163)Pinar ...
# 16  Villaverde Alto (171)San Cristóbal (172)Butarq...
# 17  Casco Histórico de Vallecas (181)Santa Eugenia...
# 18  Casco Histórico de Vicálvaro (191)Valdebernard...
# 19  Simancas (201)Hellín (202)Amposta (203)Arcos (...
# 20  Alameda de Osuna (211)Aeropuerto (212)Casco Hi...

# %% [markdown]
# It was eliminated the columns that were unuseful for the determinate the solution to the project's problem. For Barcelona, Number, Location, Density and Council were dropped from the data table. While for Madrid, it was dropped Number, Location and Density.

# %% [markdown]
# * **BARCELONA**

# %%
bcn_districts = bcn.drop(['Number','Location','Density','Council'], axis=1)
bcn_districts.District = bcn_districts.District.replace({"Gràcia": "Gracia Barcelona"})
bcn_districts
# Out:
#               District Size (km2) Population  \
# 0         Ciutat Vella       4,11    103 429
# 1             Eixample       7,46    265 910
# 2       Sants-Montjuïc      22,68    184 091
# 3            Les Corts       6,02     81 974
# 4  Sarrià-Sant Gervasi      19,91    149 260
# 5     Gracia Barcelona       4,19    121 798
# 6     Horta - Guinardó      11,96    171 495
# 7           Nou Barris       8,05    170 669
# 8          Sant Andreu       6,59    149 821
# 9           Sant Martí      10,39    238 315
#
#                                        Neighborhoods
# 0  El Raval (1), Barrio Gótico (2), La Barcelonet...
# 1  El Fort Pienc (5), Sagrada Familia (6), Dreta ...
# 2  Poble Sec (11), La Marina del Prat Vermell (12...
# 3  Les Corts (19), La Maternitat i Sant Ramon  (2...
# 4  Vallvidrera, el Tibidabo i les Planes (22), Sa...
# 5  Vallcarca i els Penitents (28), El Coll (29), ...
# 6  Baix Guinardó (33), Can Baró (34), El Guinardó...
# 7  Vilapicina i La Torre Llobeta (44), Porta (45)...
# 8  La Trinitat Vella (57), Baró de Viver (58), El...
# 9  El Camp de l'Arpa del Clot (64), El Clot (65),...

# %% [markdown]
# * **MADRID**

# %%
mad_districts = mad.drop(['Number','Location','Density'], axis=1)
mad_districts.District = mad_districts.District.replace({"Retiro": "Retiro Madrid"})
mad_districts.District = mad_districts.District.replace({"Tetuán": "Tetuán Madrid"})
mad_districts
# Out:
#                District  Size (ha) Population  \
# 0                Centro     522.82    131,928
# 1            Arganzuela     646.22    151,965
# 2         Retiro Madrid     546.62    118,516
# 3             Salamanca     539.24    143,800
# 4             Chamartín     917.55    143,424
# 5         Tetuán Madrid     537.47    153,789
# 6              Chamberí     467.92    137,401
# 7   Fuencarral-El Pardo  23,783.84    238,756
# 8       Moncloa-Aravaca   4,653.11    116,903
# 9                Latina   2,542.72    233,808
# 10          Carabanchel   1,404.83    243,998
# 11                Usera     777.77    134,791
# 12   Puente de Vallecas   1,496.86    227,595
# 13            Moratalaz     610.32     94,197
# 14        Ciudad Lineal   1,142.57    212,529
# 15            Hortaleza   2,741.98    180,462
# 16           Villaverde   2,018.76    142,608
# 17    Villa de Vallecas   5,146.72    104,421
# 18            Vicálvaro   3,526.67     70,051
# 19  San Blas-Canillejas   2,229.24    154,357
# 20              Barajas   4,192.28     46,876
#
#                                         Neighborhoods
# 0   Palacio (11)Embajadores (12)Cortes (13)Justici...
# 1   Imperial (21)Acacias (22)Chopera (23)Legazpi (...
# 2   Pacífico (31)Adelfas (32)Estrella (33)Ibiza (3...
# 3   Recoletos (41)Goya (42)Fuente del Berro (43)Gu...
# 4   El Viso (51)Prosperidad (52)Ciudad Jardín (53)...
# 5   Bellas Vistas (61)Cuatro Caminos (62)Castillej...
# 6   Gaztambide (71)Arapiles (72)Trafalgar (73)Alma...
# 7   El Pardo (81)Fuentelarreina (82)Peñagrande (83...
# 8   Casa de Campo (91)Argüelles (92)Ciudad Univers...
# 9   Los Cármenes (101)Puerta del Ángel (102)Lucero...
# 10  Comillas (111)Opañel (112)San Isidro (113)Vist...
# 11  Orcasitas (121)Orcasur (122)San Fermín (123)Al...
# 12  Entrevías (131)San Diego (132)Palomeras Bajas ...
# 13  Pavones (141)Horcajo (142)Marroquina (143)Medi...
# 14  Ventas (151)Pueblo Nuevo (152)Quintana (153)Co...
# 15  Palomas (161)Piovera (162)Canillas (163)Pinar ...
# 16  Villaverde Alto (171)San Cristóbal (172)Butarq...
# 17  Casco Histórico de Vallecas (181)Santa Eugenia...
# 18  Casco Histórico de Vicálvaro (191)Valdebernard...
# 19  Simancas (201)Hellín (202)Amposta (203)Arcos (...
# 20  Alameda de Osuna (211)Aeropuerto (212)Casco Hi...

# %% [markdown]
# As a result, the **data table** for each city was composed of the following columns list: *District, Size, Population, Neighborhoods*.

# %% [markdown]
# ### 2.3. Refining data

# %% [markdown]
# Once the list of districts was defined for each city, **geolocator** was used to determinate the location of each one of the district. Indeed, to collect all this new information it was created two new columns in the districts table: *Latitude* and *Longitude*.
#
# Another step was taken to define the data. After determinating the location of each district, it appeared that some districts were not defined correctly by the geolocator. In fact, the district *"Gracia"* had to be changed to *"Gracia Barcelona"* to be located in the correct spot. While in Madrid, the following districts had to be modified to relocate them in the correct place: *"Retiro"* by *"Retiro Madrid"* and *"Tetuan"* by *"Tetuan Madrid"*, as it was showed previously.
#
# Finally, the **districts table** for each city were composed by the following information for every district: **District**, **Size**, **Population**, **Neighborhoods**, **Latitude** and **Longitude**.

# %% [markdown]
# * **BARCELONA**

# %%
bcn_districts['Latitude'] = bcn_districts['District'].apply(lambda x: geolocator.geocode(x).latitude)
bcn_districts['Longitude'] = bcn_districts['District'].apply(lambda x: geolocator.geocode(x).longitude)
bcn_districts
# Out:
#               District Size (km2) Population  \
# 0         Ciutat Vella       4,11    103 429
# 1             Eixample       7,46    265 910
# 2       Sants-Montjuïc      22,68    184 091
# 3            Les Corts       6,02     81 974
# 4  Sarrià-Sant Gervasi      19,91    149 260
# 5     Gracia Barcelona       4,19    121 798
# 6     Horta - Guinardó      11,96    171 495
# 7           Nou Barris       8,05    170 669
# 8          Sant Andreu       6,59    149 821
# 9           Sant Martí      10,39    238 315
#
#                                        Neighborhoods   Latitude  Longitude
# 0  El Raval (1), Barrio Gótico (2), La Barcelonet...  41.374985   2.173277
# 1  El Fort Pienc (5), Sagrada Familia (6), Dreta ...  41.393689   2.163655
# 2  Poble Sec (11), La Marina del Prat Vermell (12...  41.364762   2.154233
# 3  Les Corts (19), La Maternitat i Sant Ramon  (2...  41.385244   2.132863
# 4  Vallvidrera, el Tibidabo i les Planes (22), Sa...  41.413039   2.107620
# 5  Vallcarca i els Penitents (28), El Coll (29), ...  41.410171   2.155136
# 6  Baix Guinardó (33), Can Baró (34), El Guinardó...  41.428556   2.143617
# 7  Vilapicina i La Torre Llobeta (44), Porta (45)...  41.445815   2.179801
# 8  La Trinitat Vella (57), Baró de Viver (58), El...  41.437439   2.196859
# 9  El Camp de l'Arpa del Clot (64), El Clot (65),...  41.406782   2.203655

# %% [markdown]
# * **MADRID**

# %%
mad_districts['Latitude'] = mad_districts['District'].apply(lambda x: geolocator.geocode(x).latitude)
mad_districts['Longitude'] = mad_districts['District'].apply(lambda x: geolocator.geocode(x).longitude)
mad_districts
# Out:
#                District  Size (ha) Population  \
# 0                Centro     522.82    131,928
# 1            Arganzuela     646.22    151,965
# 2         Retiro Madrid     546.62    118,516
# 3             Salamanca     539.24    143,800
# 4             Chamartín     917.55    143,424
# 5         Tetuán Madrid     537.47    153,789
# 6              Chamberí     467.92    137,401
# 7   Fuencarral-El Pardo  23,783.84    238,756
# 8       Moncloa-Aravaca   4,653.11    116,903
# 9                Latina   2,542.72    233,808
# 10          Carabanchel   1,404.83    243,998
# 11                Usera     777.77    134,791
# 12   Puente de Vallecas   1,496.86    227,595
# 13            Moratalaz     610.32     94,197
# 14        Ciudad Lineal   1,142.57    212,529
# 15            Hortaleza   2,741.98    180,462
# 16           Villaverde   2,018.76    142,608
# 17    Villa de Vallecas   5,146.72    104,421
# 18            Vicálvaro   3,526.67     70,051
# 19  San Blas-Canillejas   2,229.24    154,357
# 20              Barajas   4,192.28     46,876
#
#                                         Neighborhoods   Latitude  Longitude
# 0   Palacio (11)Embajadores (12)Cortes (13)Justici...  47.549025   1.732406
# 1   Imperial (21)Acacias (22)Chopera (23)Legazpi (...  40.398068  -3.693734
# 2   Pacífico (31)Adelfas (32)Estrella (33)Ibiza (3...  40.411150  -3.676057
# 3   Recoletos (41)Goya (42)Fuente del Berro (43)Gu...  40.965157  -5.664018
# 4   El Viso (51)Prosperidad (52)Ciudad Jardín (53)...  40.701869  -4.957008
# 5   Bellas Vistas (61)Cuatro Caminos (62)Castillej...  40.460578  -3.698281
# 6   Gaztambide (71)Arapiles (72)Trafalgar (73)Alma...  45.566267   5.920364
# 7   El Pardo (81)Fuentelarreina (82)Peñagrande (83...  40.556346  -3.778591
# 8   Casa de Campo (91)Argüelles (92)Ciudad Univers...  40.439495  -3.744204
# 9   Los Cármenes (101)Puerta del Ángel (102)Lucero...  41.459526  13.012591
# 10  Comillas (111)Opañel (112)San Isidro (113)Vist...  40.374211  -3.744676
# 11  Orcasitas (121)Orcasur (122)San Fermín (123)Al...  40.383894  -3.706446
# 12  Entrevías (131)San Diego (132)Palomeras Bajas ...  40.383553  -3.654535
# 13  Pavones (141)Horcajo (142)Marroquina (143)Medi...  40.405933  -3.644874
# 14  Ventas (151)Pueblo Nuevo (152)Quintana (153)Co...  40.448431  -3.650495
# 15  Palomas (161)Piovera (162)Canillas (163)Pinar ...  40.472549  -3.642552
# 16  Villaverde Alto (171)San Cristóbal (172)Butarq...  40.345610  -3.695956
# 17  Casco Histórico de Vallecas (181)Santa Eugenia...  40.373958  -3.612163
# 18  Casco Histórico de Vicálvaro (191)Valdebernard...  40.396584  -3.576622
# 19  Simancas (201)Hellín (202)Amposta (203)Arcos (...  40.428919  -3.604002
# 20  Alameda de Osuna (211)Aeropuerto (212)Casco Hi...  40.473318  -3.579845

# %% [markdown]
# ## 3. Methodology

# %% [markdown]
# Once the data base was determinated, the study of the project started.
#
# First, a **map** of the cities was created using **folium.Map** to visualise where was located every district. To obtain the specific localitation for both cities, it was used geolocator as well. Then, in the map, it was added a blue circle pop-up for each district to indicate exactly where is every district situate.

# %% [markdown]
# * **BARCELONA**

# %%
barcelona = 'Barcelona, Barcelona'

geolocator = Nominatim(user_agent="Micar_21")
location = geolocator.geocode(barcelona)
latitude = location.latitude
longitude = location.longitude

# %%
map_bcn = folium.Map(location=[latitude, longitude], zoom_start = 10)

for lat, lng, district, neighborhood in zip(bcn_districts['Latitude'], bcn_districts['Longitude'], bcn_districts['District'], bcn_districts['Neighborhoods']):
    label = '{}'.format(district)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
    [lat, lng],
    radius=5,
    popup=label,
    color='blue',
    fill=True,
    fill_color='#3186cc',
    fill_opacity=0.7,
    parse_html=False).add_to(map_bcn)

map_bcn
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%20%23map_674a96ad42b146109ad5d1c547debb33%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%20%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%20%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_674a96ad42b146109ad5d1c547debb33%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_674a96ad42b146109ad5d1c547debb33%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%27map_674a96ad42b146109ad5d1c547debb33%27%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7Bcenter%3A%20%5B41.3828939%2C2.1774322%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20zoom%3A%2010%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20%20%20% ...

# %% [markdown]
# * **MADRID**

# %%
madrid = 'Madrid, Madrid'

geolocator_2 = Nominatim(user_agent="Micar_21")
location_2 = geolocator_2.geocode(madrid)
latitude_2 = location_2.latitude
longitude_2 = location_2.longitude

# %%
map_mad = folium.Map(location=[latitude_2, longitude_2], zoom_start = 10)

for lat, lng, district, neighborhood in zip(mad_districts['Latitude'], mad_districts['Longitude'], mad_districts['District'], mad_districts['Neighborhoods']):
    label = '{}'.format(district)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
    [lat, lng],
    radius=5,
    popup=label,
    color='blue',
    fill=True,
    fill_color='#3186cc',
    fill_opacity=0.7,
    parse_html=False).add_to(map_mad)

map_mad
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%20%23map_035a4c0cff5b4ef49406141dcf90baea%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%20%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%20%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_035a4c0cff5b4ef49406141dcf90baea%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_035a4c0cff5b4ef49406141dcf90baea%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%27map_035a4c0cff5b4ef49406141dcf90baea%27%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7Bcenter%3A%20%5B40.4167047%2C-3.7035825%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20zoom%3A%2010%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20%20%20 ...

# %% [markdown]
# Secondly, it was define the **foursquare credentials**: Client ID, Client Secret, Access Token & Version. This step allowed to explore among different venues that exist in each district.

# %%
CLIENT_ID = 'TILJIOO41TAHQHNOEJCU3BQJ5D4PHGUEXCPT0LKQNRJWSPYO' # your Foursquare ID
CLIENT_SECRET = 'P4QZGN4PGDZPXOYD55R2NBWVENSPLM3K4JB4YNZXZLC0K4GQ' # your Foursquare Secret
ACCESS_TOKEN = 'EVSQ1WHTTHP1S5G2UZNCCR0OPFR2V5IQIHLTJNYBGEHB1W0J' # your FourSquare Access Token
VERSION = '20180604'

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: TILJIOO41TAHQHNOEJCU3BQJ5D4PHGUEXCPT0LKQNRJWSPYO
# CLIENT_SECRET:P4QZGN4PGDZPXOYD55R2NBWVENSPLM3K4JB4YNZXZLC0K4GQ

# %% [markdown]
# To explore in foursquare data base, it was necessary to create a **URL** using the personal credentials and the specific location that want to be explore. In this case, the location was defined by the latitude and longitude columns in the districts table. As a result, the URL was something like that: 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius{}&limit{}'.format(Client_ID, Client_Secret, Version, lat, lng, radius, limit). To make a test, a URL associate to one district was create to analyse the first district of each city.

# %% [markdown]
# * **BARCELONA**

# %%
bcn_districts.loc[0, 'District']
district_latitude = bcn_districts.loc[0, 'Latitude']
district_longitude = bcn_districts.loc[0, 'Longitude']
district_name = bcn_districts.loc[0, 'District']
print('Latitude and longitude values of {} are {}, {}.'.format(district_name, district_latitude, 
                                                               district_longitude))
# Out:
# Latitude and longitude values of Ciutat Vella are 41.3749846, 2.17327724224704.

# %%
LIMIT = 100
radius = 5000
url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius{}&limit{}'.format(
    CLIENT_ID, CLIENT_SECRET, VERSION,district_latitude, district_longitude, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/explore?&client_id=TILJIOO41TAHQHNOEJCU3BQJ5D4PHGUEXCPT0LKQNRJWSPYO&client_secret=P4QZGN4PGDZPXOYD55R2NBWVENSPLM3K4JB4YNZXZLC0K4GQ&v=20180604&ll=41.3749846,2.17327724224704&radius5000&limit100'

# %%
results = requests.get(url).json()

def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %% [raw]
# venues = results['response']['groups'][0]['items']
#
# nearby_venues = json_normalize(venues) # flatten JSON
#
# # filter columns
# filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
# nearby_venues =nearby_venues.loc[:, filtered_columns]
#
# # filter the category for each row
# nearby_venues['venue.categories'] = nearby_venues.apply(get_category_type, axis=1)
#
# # clean columns
# nearby_venues.columns = [col.split(".")[-1] for col in nearby_venues.columns]
#
# nearby_venues.head()

# %%
print('{} venues were returned by Foursquare.'.format(nearby_venues.shape[0]))
# Out:
# 30 venues were returned by Foursquare.

# %% [markdown]
# * **MADRID**

# %%
mad_districts.loc[0, 'District']
district_latitude_2 = mad_districts.loc[0, 'Latitude']
district_longitude_2 = mad_districts.loc[0, 'Longitude']
district_name_2 = mad_districts.loc[0, 'District']

print('Latitude and longitude values of {} are {}, {}.'.format(district_name_2, district_latitude_2, 
                                                               district_longitude_2))
# Out:
# Latitude and longitude values of Centro are 47.5490251, 1.7324062.

# %%
LIMIT =100
radius = 5000
url_2 = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius{}&limit{}'.format(
    CLIENT_ID, CLIENT_SECRET, VERSION,district_latitude_2, district_longitude_2, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/explore?&client_id=TILJIOO41TAHQHNOEJCU3BQJ5D4PHGUEXCPT0LKQNRJWSPYO&client_secret=P4QZGN4PGDZPXOYD55R2NBWVENSPLM3K4JB4YNZXZLC0K4GQ&v=20180604&ll=41.3749846,2.17327724224704&radius5000&limit100'

# %%
results_2 = requests.get(url_2).json()

def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %% [raw]
# venues_2 = results_2['response']['groups'][0]['items']
#
# nearby_venues_2 = json_normalize(venues_2) # flatten JSON
#
# # filter columns
# filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
# nearby_venues_2 =nearby_venues_2.loc[:, filtered_columns]
#
# # filter the category for each row
# nearby_venues_2['venue.categories'] = nearby_venues_2.apply(get_category_type, axis=1)
#
# # clean columns
# nearby_venues_2.columns = [col.split(".")[-1] for col in nearby_venues_2.columns]
#
# nearby_venues_2.head()

# %%
print('{} venues were returned by Foursquare.'.format(nearby_venues_2.shape[0]))
# Out:
# 7 venues were returned by Foursquare.

# %% [markdown]
# As a default, even the limit number of venues was a 100 and the radius was 5km from the location of each district, it was obtained 30 venues as highest number of venues for each district of both Barcelona and Madrid.

# %% [markdown]
# After create the URL, this was opened using **requests.get(URL).json.**. The page was open as a json file and it was used to extract different information about the different venues of each district like "venue name", "venue categories" and "venue location". All the venues were collected through getNearbyVenues and getNearbyVenues_2 for Barcelona and Madrid correspondently.

# %% [markdown]
# * **BARCELONA**

# %%
def getNearbyVenues(names, latitudes, longitudes):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius{}&limit{}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng,
            radius,
        LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['District', 
                  'District Latitude', 
                  'District Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
bcn_venues = getNearbyVenues(names=bcn_districts['District'], latitudes=bcn_districts['Latitude'], longitudes=bcn_districts['Longitude'])
# Out:
# Ciutat Vella
# Eixample
# Sants-Montjuïc
# Les Corts
# Sarrià-Sant Gervasi
# Gracia Barcelona
# Horta - Guinardó
# Nou Barris
# Sant Andreu
# Sant Martí

# %%
print(bcn_venues.shape)
bcn_venues.head()
# Out:
# (300, 7)
#        District  District Latitude  District Longitude                  Venue  \
# 0  Ciutat Vella          41.374985            2.173277                 macera
# 1  Ciutat Vella          41.374985            2.173277  The Fish & Chips Shop
# 2  Ciutat Vella          41.374985            2.173277           Cassette Bar
# 3  Ciutat Vella          41.374985            2.173277             Marea Alta
# 4  Ciutat Vella          41.374985            2.173277           Pizza Circus
#
#    Venue Latitude  Venue Longitude      Venue Category
# 0       41.375589         2.170493        Cocktail Bar
# 1       41.375965         2.174152              Bistro
# 2       41.377324         2.173629                 Bar
# 3       41.376484         2.175106  Seafood Restaurant
# 4       41.377905         2.172911         Pizza Place

# %% [markdown]
# * **MADRID**

# %%
def getNearbyVenues_2(names, latitudes, longitudes):
    
    venues_list_2=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url_2 = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius{}&limit{}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng,
            radius,
        LIMIT)
            
        # make the GET request
        results_2 = requests.get(url_2).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list_2.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results_2])

    nearby_venues_2 = pd.DataFrame([item for venue_list_2 in venues_list_2 for item in venue_list_2])
    nearby_venues_2.columns = ['District', 
                  'District Latitude', 
                  'District Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues_2)

# %%
mad_venues = getNearbyVenues_2(names=mad_districts['District'], latitudes=mad_districts['Latitude'], longitudes=mad_districts['Longitude'])
# Out:
# Centro
# Arganzuela
# Retiro Madrid
# Salamanca
# Chamartín
# Tetuán Madrid
# Chamberí
# Fuencarral-El Pardo
# Moncloa-Aravaca
# Latina
# Carabanchel
# Usera
# Puente de Vallecas
# Moratalaz
# Ciudad Lineal
# Hortaleza
# Villaverde
# Villa de Vallecas
# Vicálvaro
# San Blas-Canillejas
# Barajas

# %%
print(mad_venues.shape)
mad_venues.head()
# Out:
# (586, 7)
#   District  District Latitude  District Longitude                  Venue  \
# 0   Centro          47.549025            1.732406                   Zara
# 1   Centro          47.549025            1.732406          Gite Bellevue
# 2   Centro          47.549025            1.732406      Carrefour Contact
# 3   Centro          47.549025            1.732406             Pasteur TP
# 4   Centro          47.549025            1.732406  Alimentation Générale
#
#    Venue Latitude  Venue Longitude              Venue Category
# 0       47.612253         1.730619              Clothing Store
# 1       47.553991         1.738166             Bed & Breakfast
# 2       47.525550         1.812174                 Supermarket
# 3       47.620298         1.758394  Construction & Landscaping
# 4       47.542476         1.848846                 Supermarket

# %% [markdown]
# Once all this information about the venues of each city was obtained, the following steps were run to solve the project problem:
# * it was **group by District** to know how many venues were collected for each district.

# %% [markdown]
# * **BARCELONA**

# %%
bcn_venues_districts = bcn_venues.groupby('District').count()
bcn_venues_districts = bcn_venues_districts.drop(['District Latitude','District Longitude','Venue Latitude','Venue Longitude','Venue Category'], axis=1)
bcn_venues_districts
# Out:
#                      Venue
# District
# Ciutat Vella            30
# Eixample                30
# Gracia Barcelona        30
# Horta - Guinardó        30
# Les Corts               30
# Nou Barris              30
# Sant Andreu             30
# Sant Martí              30
# Sants-Montjuïc          30
# Sarrià-Sant Gervasi     30

# %% [markdown]
# * **MADRID**

# %%
mad_venues_districts = mad_venues.groupby('District').count()
mad_venues_districts = mad_venues_districts.drop(['District Latitude','District Longitude','Venue Latitude','Venue Longitude','Venue Category'], axis=1)
mad_venues_districts
# Out:
#                      Venue
# District
# Arganzuela              30
# Barajas                 30
# Carabanchel             30
# Centro                   7
# Chamartín                9
# Chamberí                30
# Ciudad Lineal           30
# Fuencarral-El Pardo     30
# Hortaleza               30
# Latina                  30
# Moncloa-Aravaca         30
# Moratalaz               30
# Puente de Vallecas      30
# Retiro Madrid           30
# Salamanca               30
# San Blas-Canillejas     30
# Tetuán Madrid           30
# Usera                   30
# Vicálvaro               30
# Villa de Vallecas       30
# Villaverde              30

# %% [markdown]
# * Then, **venue_category** was created to represent the total number of venues of each category exists in each city.

# %% [markdown]
# * **BARCELONA**

# %%
venue_category_bcn = bcn_venues.groupby('Venue Category').count() 
venue_category_bcn = venue_category_bcn.drop(['District Latitude','District Longitude', 'Venue','Venue Latitude','Venue Longitude'], axis=1)
venue_category_bcn = venue_category_bcn.sort_values(by=['District'], ascending=[False])
venue_category_bcn
# Out:
#                                District
# Venue Category
# Restaurant                           16
# Park                                 15
# Tapas Restaurant                     14
# Spanish Restaurant                   14
# Mediterranean Restaurant             13
# Hotel                                10
# Plaza                                10
# Scenic Lookout                        7
# Pizza Place                           7
# Bakery                                7
# Bar                                   6
# Brewery                               6
# Café                                  5
# Coffee Shop                           5
# Garden                                5
# Italian Restaurant                    5
# Theater                               5
# Cocktail Bar                          5
# Boutique                              4
# Gym                                   4
# Supermarket                           4
# Monument / Landmark                   4
# Gym / Fitness Center                  4
# Shopping Mall                         3
# Museum                                3
# Grocery Store                         3
# Argentinian Restaurant                3
# Burger Joint                          3
# Beer Bar                              3
# Art Museum                            3
# Coworking Space                       3
# Salad Place                           2
# Theme Park                            2
# Sporting Goods Shop                   2
# Mountain                              2
# Castle                                2
# Mexican Restaurant                    2
# Art Gallery                           2
# Soccer Field                          2
# Building                              2
# Sushi Restaurant                      2
# Performing Arts Venue                 2
# Tennis Court                          2
# Clothing Store                        2
# Organic Grocery                       2
# Vegetarian / Vegan Restaurant         2
# Sandwich Place                        2
# Gastropub                             2
# Bistro                                2
# Trail                                 2
# Fountain                              2
# Donut Shop                            2
# Electronics Store                     2
# Food                                  2
# Spa                                   1
# Beer Store                            1
# Seafood Restaurant                    1
# Snack Place                           1
# Skate Park                            1
# Sculpture Garden                      1
# Science Museum                        1
# Dance Studio                          1
# Bed & Breakfast                       1
# Sports Club                           1
# Stadium                               1
# Roof Deck                             1
# Taco Place                            1
# Asian Restaurant                      1
# Thai Restaurant                       1
# Theme Park Ride / Attraction          1
# Track                                 1
# Train Station                         1
# Transportation Service                1
# Wine Bar                              1
# Wine Shop                             1
# Basketball Stadium                    1
# Pie Shop                              1
# Rock Club                             1
# Road                                  1
# Dessert Shop                          1
# Diner                                 1
# Empanada Restaurant                   1
# Flea Market                           1
# Food & Drink Shop                     1
# Cupcake Shop                          1
# General College & University          1
# German Restaurant                     1
# Concert Hall                          1
# Hardware Store                        1
# Hill                                  1
# Historic Site                         1
# Church                                1
# Ice Cream Shop                        1
# Indie Movie Theater                   1
# Chinese Restaurant                    1
# Japanese Restaurant                   1
# Market                                1
# Movie Theater                         1
# Music Venue                           1
# National Park                         1
# Palace                                1
# Pedestrian Plaza                      1
# Photography Lab                       1
# Deli / Bodega                         1
# Breakfast Spot                        1
# Bookstore                             1
# Polish Restaurant                     1
# Pool                                  1
# Winery                                1

# %% [markdown]
# * **MADRID**

# %%
venue_category_mad = mad_venues.groupby('Venue Category').count() 
venue_category_mad = venue_category_mad.drop(['District Latitude','District Longitude', 'Venue','Venue Latitude','Venue Longitude'], axis=1)
venue_category_mad = venue_category_mad.sort_values(by=['District'], ascending=[False])
venue_category_mad
# Out:
#                                District
# Venue Category
# Spanish Restaurant                   60
# Park                                 30
# Restaurant                           21
# Italian Restaurant                   17
# Gym                                  17
# Tapas Restaurant                     17
# Bar                                  16
# Supermarket                          16
# Hotel                                16
# Pub                                  15
# Café                                 12
# Pizza Place                          12
# Ice Cream Shop                       11
# Coffee Shop                          10
# Grocery Store                         9
# Bakery                                9
# Gastropub                             8
# Plaza                                 8
# Exhibit                               8
# Gym / Fitness Center                  8
# Argentinian Restaurant                8
# Garden                                7
# Scenic Lookout                        6
# Seafood Restaurant                    6
# Chinese Restaurant                    6
# Asian Restaurant                      5
# Tennis Court                          5
# Brewery                               5
# Mediterranean Restaurant              5
# Construction & Landscaping            5
# Pool                                  4
# French Restaurant                     4
# Rock Club                             4
# Furniture / Home Store                4
# Dessert Shop                          4
# Athletics & Sports                    4
# Monument / Landmark                   4
# Art Museum                            4
# Cocktail Bar                          4
# Beer Garden                           4
# Burger Joint                          4
# Museum                                4
# Sandwich Place                        4
# Mexican Restaurant                    3
# Paella Restaurant                     3
# Market                                3
# Japanese Restaurant                   3
# Fast Food Restaurant                  3
# Clothing Store                        3
# Art Gallery                           3
# BBQ Joint                             3
# Bookstore                             3
# Sporting Goods Shop                   3
# Farmers Market                        3
# Soccer Field                          3
# Soccer Stadium                        3
# Shopping Mall                         3
# Cupcake Shop                          3
# Diner                                 3
# Electronics Store                     3
# Snack Place                           2
# Neighborhood                          2
# Music Venue                           2
# Steakhouse                            2
# Multiplex                             2
# Sushi Restaurant                      2
# Peruvian Restaurant                   2
# Thai Restaurant                       2
# Pharmacy                              2
# Vegetarian / Vegan Restaurant         2
# Juice Bar                             2
# Indie Movie Theater                   2
# Wine Bar                              2
# Eastern European Restaurant           2
# Beer Bar                              2
# Department Store                      2
# Deli / Bodega                         2
# Concert Hall                          2
# Comedy Club                           2
# Church                                2
# Golf Course                           2
# Government Building                   2
# Bistro                                2
# Breakfast Spot                        2
# Indie Theater                         2
# Auto Garage                           2
# Toy / Game Store                      1
# Resort                                1
# Dumpling Restaurant                   1
# Donut Shop                            1
# Venezuelan Restaurant                 1
# Airport Lounge                        1
# Cuban Restaurant                      1
# Trail                                 1
# Skating Rink                          1
# Trade School                          1
# Bed & Breakfast                       1
# Tattoo Parlor                         1
# Art Studio                            1
# Social Club                           1
# Soup Place                            1
# Bubble Tea Shop                       1
# Rental Car Location                   1
# Sports Club                           1
# Stadium                               1
# Brazilian Restaurant                  1
# Candy Store                           1
# Irish Pub                             1
# Racetrack                             1
# Gym Pool                              1
# Korean Restaurant                     1
# Latin American Restaurant             1
# Light Rail Station                    1
# Lounge                                1
# Airport                               1
# Indian Restaurant                     1
# Hotel Bar                             1
# Middle Eastern Restaurant             1
# Hostel                                1
# Motorcycle Shop                       1
# Movie Theater                         1
# History Museum                        1
# Historic Site                         1
# Nightclub                             1
# Event Space                           1
# Noodle House                          1
# Office                                1
# Gourmet Shop                          1
# Pastry Shop                           1
# Performing Arts Venue                 1
# Persian Restaurant                    1
# Food Service                          1
# Pet Store                             1
# Food Court                            1
# Food                                  1
# Playground                            1
# Flea Market                           1
# Polish Restaurant                     1
# Accessories Store                     1

# %% [markdown]
# * The previous step helped to elaborate a list of *Venue Category* that was related only to **Hospitality**.

# %% [markdown]
# * **BARCELONA**

# %%
hospitality_bcn = bcn_venues[bcn_venues['Venue Category'].isin(['Argentinian Restaurant','Asian Restaurant','Bakery','Bar','Bed & Breakfast','Beer Bar','Bistro','Breakfast Spot','Burger Joint','Café','Chinese Restaurant','Cocktail Bar','Coffee Shop','Cupcake Shop','Deli/Bodega','Dessert Shop','Diner','Donut Shop','Empanada Restaurant','Food','Food & Drink Shop','Gastropub','German Restaurant','Hotel','Ice Cream Shop','Italian Restaurant','Japanese Restaurant','Mediterranean Restaurant','Mexican Restaurant','Pizza Place','Polish Restaurant','Restaurant','Sandwich Place','Seafood Restaurant','Snack Placce','Spanish Restaurant','Sushi Restaurant','Taco Place','Tapas Restaurant','Thai Restaurant','Vegetarian/Vegan Restaurant','Wine Bar'])]
print(hospitality_bcn.shape)
hospitality_bcn
# Out:
# (147, 7)
#                 District  District Latitude  District Longitude  \
# 0           Ciutat Vella          41.374985            2.173277
# 1           Ciutat Vella          41.374985            2.173277
# 2           Ciutat Vella          41.374985            2.173277
# 3           Ciutat Vella          41.374985            2.173277
# 4           Ciutat Vella          41.374985            2.173277
# 7           Ciutat Vella          41.374985            2.173277
# 9           Ciutat Vella          41.374985            2.173277
# 10          Ciutat Vella          41.374985            2.173277
# 15          Ciutat Vella          41.374985            2.173277
# 17          Ciutat Vella          41.374985            2.173277
# 19          Ciutat Vella          41.374985            2.173277
# 23          Ciutat Vella          41.374985            2.173277
# 24          Ciutat Vella          41.374985            2.173277
# 283                         Can Recasens       41.402376         2.199777
# 284                    Papa John's Pizza       41.407790         2.205198
# 285                             Traspaso       41.405062         2.209947
# 286     The Level at Meliá Barcelona Sky       41.406144         2.200861
# 287                              Baluard       41.402418         2.201460
# 289           La Picantería de l'Escribà       41.402058         2.202043
# 290                             Kalamata       41.403885         2.198540
# 291                     Tierra del fuego       41.401815         2.201369
# 292                    Bitácora Poblenou       41.401149         2.204652
# 293                             Fisterra       41.409050         2.208077
# 294                    Las Muns Poblenou       41.403772         2.196754
# 295                              Monopol       41.401277         2.201178
# 296                          Little Fern       41.402232         2.197312
# 299                               Minyam       41.402346         2.201479
#
#                Venue Category
# 0                Cocktail Bar
# 1                      Bistro
# 2                         Bar
# 3          Seafood Restaurant
# 4                 Pizza Place
# 7          Mexican Restaurant
# 9          Spanish Restaurant
# 10                Pizza Place
# 15           Tapas Restaurant
# 17                 Restaurant
# 19               Cocktail Bar
# 23                Coffee Shop
# 24           Tapas Restaurant
# 25                      Hotel
# 26         Spanish Restaurant
# 27               Cocktail Bar
# 28         Spanish Restaurant
# 29               Cocktail Bar
# 30                      Hotel
# 31                      Hotel
# 32           Tapas Restaurant
# 33                      Hotel
# 34                      Hotel
# 42     Argentinian Restaurant
# 45                   Beer Bar
# 46               Burger Joint
# 47            Bed & Breakfast
# 48           Tapas Restaurant
# 49                     Bakery
# 52         Spanish Restaurant
# 53                     Bakery
# 55   Mediterranean Restaurant
# 56                      Hotel
# 57        Japanese Restaurant
# 58                     Bakery
# 59                      Hotel
# 82         Italian Restaurant
# 84                 Restaurant
# 89                Pizza Place
# 90                       Café
# 91                 Restaurant
# 92           Tapas Restaurant
# 94                 Restaurant
# 95   Mediterranean Restaurant
# 97         Spanish Restaurant
# 98           Asian Restaurant
# 99            Thai Restaurant
# 100                    Bakery
# 101         Polish Restaurant
# 102               Pizza Place
# 104               Coffee Shop
# 106                      Café
# 108                  Beer Bar
# 111              Cocktail Bar
# 112                Restaurant
# 113        Chinese Restaurant
# 114                 Gastropub
# 116                     Hotel
# 119          Sushi Restaurant
# 120            Ice Cream Shop
# 133                     Hotel
# 134              Burger Joint
# 141  Mediterranean Restaurant
# 142              Cupcake Shop
# 144  Mediterranean Restaurant
# 145        Spanish Restaurant
# 150                 Gastropub
# 151          Tapas Restaurant
# 152                Restaurant
# 153                Restaurant
# 157        Mexican Restaurant
# 159                       Bar
# 164              Dessert Shop
# 166                Donut Shop
# 167            Sandwich Place
# 168                       Bar
# 169                Donut Shop
# 172                    Bistro
# 173                  Wine Bar
# 174          Sushi Restaurant
# 176          Tapas Restaurant
# 178                Restaurant
# 179        Italian Restaurant
# 180    Argentinian Restaurant
# 181        Spanish Restaurant
# 182        Spanish Restaurant
# 186         Food & Drink Shop
# 193                Restaurant
# 194            Sandwich Place
# 196        Spanish Restaurant
# 197                      Café
# 199          Tapas Restaurant
# 200                Restaurant
# 202        Spanish Restaurant
# 206        Spanish Restaurant
# 208         German Restaurant
# 209        Spanish Restaurant
# 213        Spanish Restaurant
# 214               Pizza Place
# 215          Tapas Restaurant
# 216          Tapas Restaurant
# 217        Italian Restaurant
# 218                Restaurant
# 220  Mediterranean Restaurant
# 221          Tapas Restaurant
# 231          Tapas Restaurant
# 234               Coffee Shop
# 235                     Diner
# 236                  Beer Bar
# 239                      Food
# 246              Burger Joint
# 247          Tapas Restaurant
# 248               Coffee Shop
# 251                Restaurant
# 253               Coffee Shop
# 254                      Food
# 258                       Bar
# 259                Restaurant
# 261               Pizza Place
# 262                       Bar
# 264        Italian Restaurant
# 266  Mediterranean Restaurant
# 267                      Café
# 269                      Café
# 270                Taco Place
# 273                    Bakery
# 274  Mediterranean Restaurant
# 275                Restaurant
# 276        Spanish Restaurant
# 279  Mediterranean Restaurant
# 280                    Bakery
# 281  Mediterranean Restaurant
# 282        Italian Restaurant
# 283  Mediterranean Restaurant
# 284               Pizza Place
# 285  Mediterranean Restaurant
# 286                     Hotel
# 287                    Bakery
# 289                Restaurant
# 290          Tapas Restaurant
# 291    Argentinian Restaurant
# 292  Mediterranean Restaurant
# 293  Mediterranean Restaurant
# 294       Empanada Restaurant
# 295                       Bar
# 296            Breakfast Spot
# 299                Restaurant

# %% [markdown]
# * **MADRID**

# %%
hospitality_mad = mad_venues[mad_venues['Venue Category'].isin(['Argentinian Restaurant','Asian Restaurant','BBQ Joint','Bakery','Bar','Beer Bar','Beer Garden','Bistro','Brazilian Restaurant','Breakfast Spot','Burger Joint','Café','Chinese Restaurant','Cocktail Bar','Coffee Shop','Cuban Restaurant','Cupcake Shop','Deli/Bodega','Dessert Shop','Diner','Donut Shop','Dumpling Restaurant','Eastern European Restaurant','Fast Food Restaurant','Food Service','French Restaurant','Gastropub','Hotel','Hotel Bar','Ice Cream Shop','Indian Restaurant','Italian Restaurant','Japanese Restaurant','Juice Bar','Korean Restaurant','Latin American Restaurant','Mediterranean Restaurant','Mexican Restaurant','Middle Eastern Restaurant','Paella Restaurant','Pastry Shop','Persian Restaurant','Peruvian Restaurant','Pizza Place','Polish Restaurant','Restaurant','Sandwich Place','Seafood Restaurant','Snack Placce','Soup Place','Spanish Restaurant','Steakhouse','Sushi Restaurant','Tapas Restaurant','Thai Restaurant','Vegetarian/Vegan Restaurant','Venezuelan Restaurant','Wine Bar'])]
print(hospitality_mad.shape)
hospitality_mad
# Out:
# (319, 7)
#                 District  District Latitude  District Longitude  \
# 5                 Centro          47.549025            1.732406
# 7             Arganzuela          40.398068           -3.693734
# 10            Arganzuela          40.398068           -3.693734
# 11            Arganzuela          40.398068           -3.693734
# 12            Arganzuela          40.398068           -3.693734
# 14            Arganzuela          40.398068           -3.693734
# 15            Arganzuela          40.398068           -3.693734
# 16            Arganzuela          40.398068           -3.693734
# 17            Arganzuela          40.398068           -3.693734
# 18            Arganzuela          40.398068           -3.693734
# 20            Arganzuela          40.398068           -3.693734
# 21            Arganzuela          40.398068           -3.693734
# 25            Arganzuela          40.398068           -3.693734
# 26            Arganzuela          40.398068           -3.693734
# 27            Arganzuela          40.398068           -3.693734
# 268          Carabanchel          40.374211           -3.744676
# 269          Carabanchel          40.374211           -3.744676
# 271          Carabanchel          40.374211           -3.744676
# 272          Carabanchel          40.374211           -3.744676
# 274          Carabanchel          40.374211           -3.744676
# 276          Carabanchel          40.374211           -3.744676
# 278          Carabanchel          40.374211           -3.744676
# 279          Carabanchel          40.374211           -3.744676
# 281          Carabanchel          40.374211           -3.744676
# 283          Carabanchel          40.374211           -3.744676
# 284          Carabanchel          40.374211           -3.744676
# 285          Carabanchel          40.374211           -3.744676
# 286                Usera          40.383894           -3.706446
# 287                Usera          40.383894           -3.706446
# 289                Usera          40.383894           -3.706446
# 291                Usera          40.383894           -3.706446
# 297                Usera          40.383894           -3.706446
# 300                Usera          40.383894           -3.706446
# 301                Usera          40.383894           -3.706446
# 303                Usera          40.383894           -3.706446
# 305                Usera          40.383894           -3.706446
# 307                Usera          40.383894           -3.706446
# 311                Usera          40.383894           -3.706446
# 312                Usera          40.383894           -3.706446
# 313                Usera          40.383894           -3.706446
# 318   Puente de Vallecas          40.383553           -3.654535
# 327   Puente de Vallecas          40.383553           -3.654535
# 328   Puente de Vallecas          40.383553           -3.654535
# 329   Puente de Vallecas          40.383553           -3.654535
# 331   Puente de Vallecas          40.383553           -3.654535
# 332   Puente de Vallecas          40.383553           -3.654535
# 333   Puente de Vallecas          40.383553           -3.654535
# 335   Puente de Vallecas          40.383553           -3.654535
# 339   Puente de Vallecas          40.383553           -3.654535
# 342   Puente de Vallecas          40.383553           -3.654535
# 343   Puente de Vallecas          40.383553           -3.654535
# 344   Puente de Vallecas          40.383553           -3.654535
# 353            Moratalaz          40.405933           -3.644874
# 354            Moratalaz          40.405933           -3.644874
# 358            Moratalaz          40.405933           -3.644874
# 360            Moratalaz          40.405933           -3.644874
# 364            Moratalaz          40.405933           -3.644874
# 367            Moratalaz          40.405933           -3.644874
# 370            Moratalaz          40.405933           -3.644874
# 373            Moratalaz          40.405933           -3.644874
# 374            Moratalaz          40.405933           -3.644874
# 375            Moratalaz          40.405933           -3.644874
# 376        Ciudad Lineal          40.448431           -3.650495
# 377        Ciudad Lineal          40.448431           -3.650495
# 378        Ciudad Lineal          40.448431           -3.650495
# 379        Ciudad Lineal          40.448431           -3.650495
# 380        Ciudad Lineal          40.448431           -3.650495
# 382        Ciudad Lineal          40.448431           -3.650495
# 383        Ciudad Lineal          40.448431           -3.650495
# 385        Ciudad Lineal          40.448431           -3.650495
# 386        Ciudad Lineal          40.448431           -3.650495
# 388        Ciudad Lineal          40.448431           -3.650495
# 389        Ciudad Lineal          40.448431           -3.650495
# 390        Ciudad Lineal          40.448431           -3.650495
# 391        Ciudad Lineal          40.448431           -3.650495
# 392        Ciudad Lineal          40.448431           -3.650495
# 394        Ciudad Lineal          40.448431           -3.650495
# 395        Ciudad Lineal          40.448431           -3.650495
# 396        Ciudad Lineal          40.448431           -3.650495
# 397        Ciudad Lineal          40.448431           -3.650495
# 398        Ciudad Lineal          40.448431           -3.650495
# 402        Ciudad Lineal          40.448431           -3.650495
# 272          Pastelería-Panadería La Gallega       40.384049        -3.746432
# 274                              Passaparola       40.388032        -3.765900
# 276                                 Devinums       40.382068        -3.748143
# 278                              Pizza Pazza       40.375095        -3.774840
# 279                              Tommy Mel's       40.363375        -3.738951
# 281                                  Kalenda       40.387187        -3.752321
# 283                  Cafeteria La Picota III       40.372664        -3.740503
# 284                                 Aynaelda       40.396080        -3.753930
# 285                                Starbucks       40.363503        -3.736551
# 286                      La Fonda Colombiana       40.385709        -3.704868
# 287                          La Peña Soriana       40.382060        -3.711332
# 289                           Royal Cantonés       40.383224        -3.702585
# 291                               i go pasta       40.382730        -3.710675
# 297                                Starbucks       40.391304        -3.701123
# 300                 La Parrilla de Usera III       40.385785        -3.703235
# 301                                Feito Rio       40.391494        -3.703056
# 303                   Trattoria In Crescendo       40.394582        -3.698388
# 305                        Panaderia Granier       40.386125        -3.704018
# 307                        La Casa Del Pulpo       40.387182        -3.700447
# 311                   La Gelateria di Angelo       40.397951        -3.707739
# 312            Pulpería Restaurante O'Freixo       40.387071        -3.714572
# 313                        Bodega La Amistad       40.386604        -3.714995
# 318                         El Fogon de Paco       40.381871        -3.648510
# 327                                Casa Doli       40.386690        -3.668193
# 328                              la lonjeria       40.383406        -3.630373
# 329                             Pon de Beber       40.388773        -3.654377
# 331               Restaurante Puerta Bisagra       40.401819        -3.660041
# 332                 Callao24 by Jhosef Arias       40.397976        -3.667130
# 333                                  Tu Situ       40.393794        -3.675602
# 335               Bar Las Cervecitas (Santi)       40.386039        -3.649361
# 339                          Taberna Búlgara       40.403223        -3.663090
# 342              Tablao Flamenco Los Porches       40.387906        -3.672517
# 343                                  Vientos       40.396648        -3.669706
# 344        Churreria Siglo XIX Avda Albufera       40.387245        -3.639695
# 353                               Bar Gredos       40.408693        -3.652242
# 354               Restaurante Puerta Bisagra       40.401819        -3.660041
# 358                          Taberna Búlgara       40.403223        -3.663090
# 360                           Hotel Claridge       40.406584        -3.669890
# 364                             Bare Nostrum       40.406548        -3.650240
# 367                                La Fornía       40.424986        -3.654087
# 370                                   Trasgu       40.397450        -3.620756
# 373                 Callao24 by Jhosef Arias       40.397976        -3.667130
# 374                                Las 3 Rrr       40.394861        -3.642402
# 375                              Casa Manolo       40.398448        -3.623989
# 376                   Los Quesos de l'Amelie       40.451040        -3.649630
# 377                          Pastelería Vait       40.449958        -3.650562
# 378                                Casa Lobo       40.451620        -3.649749
# 379                        La Vaca Argentina       40.451483        -3.649788
# 380         hotel artiem madrid fresh people       40.442613        -3.647919
# 382                              Sweet Suomi       40.444125        -3.654848
# 383                                  Taruffi       40.450109        -3.650449
# 385                            Sabor Azafrán       40.445006        -3.641072
# 386                        Pappone Trattoria       40.444030        -3.654328
# 388                     La Casita del Pradal       40.458509        -3.655370
# 389                                Bar Ruval       40.440334        -3.649833
# 390                                The Knife       40.450156        -3.649647
# 391                            El Rinconcito       40.448139        -3.664144
# 392                      Cervecería Olivares       40.437265        -3.650481
# 394                           Zoila Catering       40.446264        -3.643536
# 510                                   Trasgu       40.397450        -3.620756
# 514                      Cervecería Jaén III       40.420492        -3.567863
# 517                                Five Guys       40.368706        -3.598228
# 519                           100 Montaditos       40.404233        -3.609993
# 520                                7 Pecados       40.380083        -3.538200
# 521                                Alquitara       40.406181        -3.605926
# 522                            Handicap Café       40.400448        -3.609577
# 525                         Cervecería Uceda       40.420320        -3.613981
# 531                         Cervecería Uceda       40.420320        -3.613981
# 532                                 Ó Camiňo       40.426458        -3.604320
# 533                        Restaurante Mulan       40.421778        -3.609434
# 534                                  Faborit       40.433005        -3.628091
# 535                                Jaizkibel       40.438885        -3.622630
# 539                                   Kaloan       40.431670        -3.633348
# 541                     Restaurante Victoria       40.422401        -3.612089
# 543                                 Fanático       40.439160        -3.629697
# 544                                   O'bico       40.438275        -3.625662
# 545                                El Desván       40.420435        -3.613891
# 546                      El Rincon Del Jamon       40.431886        -3.626997
# 547                         Taberna de Yuste       40.436374        -3.623462
# 548                      Barceló Torre Arias       40.434424        -3.630356
# 549                                Seis Ocho       40.438452        -3.623844
# 550                              Cascanueces       40.436571        -3.630258
# 551                                 PANISHOP       40.437971        -3.618782
# 552                           La Tagliatella       40.440465        -3.628550
# 553                                Demimadre       40.436393        -3.623480
# 555                                 El Horno       40.434407        -3.629258
# 556                               La General       40.470646        -3.580571
# 557                             Finca Lucero       40.470693        -3.583052
# 558                    Taberna La Caprichosa       40.473318        -3.577521
# 560                            Bahía Taberna       40.463668        -3.592166
# 561                      Asador Nuevo Porche       40.470895        -3.582518
# 562                         La Viña de Nerea       40.472329        -3.581817
# 563                        Okela Restsursnte       40.472205        -3.581692
# 564                                Martes 13       40.473022        -3.581973
# 565                          Kirei by Kabuki       40.490557        -3.591285
# 566                              Bar La Caña       40.462076        -3.590485
# 567                                    La 28       40.457335        -3.585759
# 569                                Al Traste       40.470539        -3.580691
# 570                      Churrería Siglo XIX       40.473623        -3.577137
# 573     Hotel Ibis Madrid Aeropuerto Barajas       40.469835        -3.580748
# 575                            The Glass Bar       40.469899        -3.588425
# 577                       Mesón Don Fernando       40.470794        -3.581140
# 578                  El Brasero de Don Pedro       40.449366        -3.571279
# 579                                La Torino       40.473706        -3.578169
# 580                             Sushi & Buey       40.470506        -3.581520
# 584                     Hotel Maydrit Madrid       40.451555        -3.592790
# 585                             Os Ferreiros       40.465643        -3.587073
#
#                   Venue Category
# 5                     Restaurant
# 7             Chinese Restaurant
# 10                    Restaurant
# 11              Tapas Restaurant
# 12                        Bakery
# 14                  Cocktail Bar
# 15            Italian Restaurant
# 16              Cuban Restaurant
# 17              Tapas Restaurant
# 18                     Gastropub
# 20            Spanish Restaurant
# 21             Korean Restaurant
# 25               Thai Restaurant
# 26                      Beer Bar
# 27                   Coffee Shop
# 32        Argentinian Restaurant
# 35                Ice Cream Shop
# 39            Spanish Restaurant
# 42            Mexican Restaurant
# 43            Italian Restaurant
# 44            Spanish Restaurant
# 47                  Cupcake Shop
# 51                         Hotel
# 52        Argentinian Restaurant
# 53                  Burger Joint
# 55                        Bakery
# 56              Tapas Restaurant
# 59              Tapas Restaurant
# 60                Ice Cream Shop
# 61             Polish Restaurant
# 62              Tapas Restaurant
# 64              Tapas Restaurant
# 66                    Restaurant
# 68              Tapas Restaurant
# 70                      Wine Bar
# 71                  Cocktail Bar
# 72                     Hotel Bar
# 73            Italian Restaurant
# 74                  Cocktail Bar
# 75                      Wine Bar
# 76                  Dessert Shop
# 81                  Dessert Shop
# 82              Tapas Restaurant
# 83            Spanish Restaurant
# 84              Tapas Restaurant
# 85                Sandwich Place
# 86            Spanish Restaurant
# 92            Spanish Restaurant
# 94                           Bar
# 95                         Hotel
# 96                           Bar
# 102           Mexican Restaurant
# 103                        Hotel
# 105                   Steakhouse
# 106           Spanish Restaurant
# 108                          Bar
# 110           Chinese Restaurant
# 111           Spanish Restaurant
# 112         Brazilian Restaurant
# 113           Spanish Restaurant
# 115             Asian Restaurant
# 117           Spanish Restaurant
# 118             Tapas Restaurant
# 120           Seafood Restaurant
# 121                        Hotel
# 122                  Pizza Place
# 124                        Hotel
# 125           Spanish Restaurant
# 126           Italian Restaurant
# 127            Paella Restaurant
# 128           Spanish Restaurant
# 129             Sushi Restaurant
# 130           Spanish Restaurant
# 131           Spanish Restaurant
# 132           Spanish Restaurant
# 133               Breakfast Spot
# 134                        Hotel
# 137            French Restaurant
# 141            French Restaurant
# 144                  Coffee Shop
# 146                        Hotel
# 147                        Hotel
# 149            French Restaurant
# 150                        Hotel
# 158                    Gastropub
# 159                  Coffee Shop
# 160            French Restaurant
# 161                   Steakhouse
# 163                        Hotel
# 167           Spanish Restaurant
# 168                   Restaurant
# 169     Mediterranean Restaurant
# 170           Spanish Restaurant
# 172                  Coffee Shop
# 173                 Dessert Shop
# 174       Argentinian Restaurant
# 175           Seafood Restaurant
# 176                   Restaurant
# 177                 Dessert Shop
# 178               Ice Cream Shop
# 179                 Burger Joint
# 180           Spanish Restaurant
# 183           Spanish Restaurant
# 184                  Pizza Place
# 186       Argentinian Restaurant
# 192                        Diner
# 205                  Pastry Shop
# 206             Tapas Restaurant
# 207           Italian Restaurant
# 208               Ice Cream Shop
# 209          Japanese Restaurant
# 210                  Pizza Place
# 211           Spanish Restaurant
# 213                   Restaurant
# 214           Spanish Restaurant
# 216          Dumpling Restaurant
# 217                  Coffee Shop
# 218                  Beer Garden
# 220                         Café
# 221            Paella Restaurant
# 222                         Café
# 224           Spanish Restaurant
# 226                        Hotel
# 229                  Pizza Place
# 230                  Pizza Place
# 231           Italian Restaurant
# 232               Ice Cream Shop
# 234           Italian Restaurant
# 235         Fast Food Restaurant
# 237               Ice Cream Shop
# 240                  Pizza Place
# 241         Fast Food Restaurant
# 242           Italian Restaurant
# 243                  Pizza Place
# 245                    Gastropub
# 246                        Diner
# 247                         Café
# 248               Ice Cream Shop
# 250           Italian Restaurant
# 251                 Cupcake Shop
# 252                       Bistro
# 254                         Café
# 255                 Cocktail Bar
# 256                    Gastropub
# 257           Spanish Restaurant
# 259                    BBQ Joint
# 264             Tapas Restaurant
# 266           Italian Restaurant
# 268           Spanish Restaurant
# 269           Italian Restaurant
# 271                          Bar
# 272                       Bakery
# 274           Italian Restaurant
# 276             Tapas Restaurant
# 278                  Pizza Place
# 279                        Diner
# 281                   Restaurant
# 283                         Café
# 284            Paella Restaurant
# 285                  Coffee Shop
# 286                   Restaurant
# 287           Spanish Restaurant
# 289           Chinese Restaurant
# 291             Asian Restaurant
# 297                  Coffee Shop
# 300                    BBQ Joint
# 301                    Gastropub
# 303           Italian Restaurant
# 305                       Bakery
# 307           Spanish Restaurant
# 311               Ice Cream Shop
# 312           Seafood Restaurant
# 313                          Bar
# 318           Spanish Restaurant
# 327           Spanish Restaurant
# 328           Seafood Restaurant
# 329                          Bar
# 331                   Restaurant
# 332          Peruvian Restaurant
# 333                         Café
# 335                          Bar
# 339  Eastern European Restaurant
# 342                   Restaurant
# 343                          Bar
# 344                         Café
# 353                          Bar
# 354                   Restaurant
# 358  Eastern European Restaurant
# 360                        Hotel
# 364                          Bar
# 367                          Bar
# 370           Spanish Restaurant
# 373          Peruvian Restaurant
# 374     Mediterranean Restaurant
# 375           Spanish Restaurant
# 376                    Gastropub
# 377                       Bakery
# 378           Spanish Restaurant
# 379       Argentinian Restaurant
# 380                        Hotel
# 382                  Coffee Shop
# 383               Ice Cream Shop
# 385           Persian Restaurant
# 386           Italian Restaurant
# 388           Spanish Restaurant
# 389           Spanish Restaurant
# 390       Argentinian Restaurant
# 391           Spanish Restaurant
# 392                          Bar
# 394                 Food Service
# 395             Tapas Restaurant
# 396           Spanish Restaurant
# 397                          Bar
# 398                   Restaurant
# 402    Middle Eastern Restaurant
# 404             Asian Restaurant
# 406           Spanish Restaurant
# 407                  Pizza Place
# 408        Venezuelan Restaurant
# 409            Indian Restaurant
# 411           Spanish Restaurant
# 412             Tapas Restaurant
# 413             Sushi Restaurant
# 415                   Soup Place
# 417     Mediterranean Restaurant
# 418           Spanish Restaurant
# 419           Spanish Restaurant
# 421           Spanish Restaurant
# 422                    Juice Bar
# 423                    Juice Bar
# 426             Asian Restaurant
# 427           Chinese Restaurant
# 428           Spanish Restaurant
# 429                       Bakery
# 430                   Restaurant
# 432                  Beer Garden
# 433              Thai Restaurant
# 435           Spanish Restaurant
# 437    Latin American Restaurant
# 438           Spanish Restaurant
# 444                   Restaurant
# 445           Spanish Restaurant
# 446                          Bar
# 450           Spanish Restaurant
# 452                         Café
# 453                    Gastropub
# 455                   Donut Shop
# 456           Italian Restaurant
# 458           Spanish Restaurant
# 463           Spanish Restaurant
# 465           Chinese Restaurant
# 466                       Bakery
# 471           Seafood Restaurant
# 473                 Burger Joint
# 474                   Restaurant
# 483                 Cupcake Shop
# 484           Spanish Restaurant
# 486           Spanish Restaurant
# 488               Ice Cream Shop
# 492                   Restaurant
# 493           Italian Restaurant
# 494                  Coffee Shop
# 495         Fast Food Restaurant
# 496     Mediterranean Restaurant
# 497           Spanish Restaurant
# 498               Ice Cream Shop
# 499                   Restaurant
# 502                  Pizza Place
# 503                    BBQ Joint
# 504                  Pizza Place
# 508                  Pizza Place
# 510           Spanish Restaurant
# 514                          Bar
# 517                 Burger Joint
# 519               Sandwich Place
# 520             Tapas Restaurant
# 521                     Beer Bar
# 522                         Café
# 525                  Beer Garden
# 531                  Beer Garden
# 532           Seafood Restaurant
# 533           Chinese Restaurant
# 534                         Café
# 535           Spanish Restaurant
# 539                         Café
# 541             Asian Restaurant
# 543                  Coffee Shop
# 544                   Restaurant
# 545                   Restaurant
# 546           Spanish Restaurant
# 547                          Bar
# 548                        Hotel
# 549     Mediterranean Restaurant
# 550                         Café
# 551               Sandwich Place
# 552           Italian Restaurant
# 553               Sandwich Place
# 555                       Bakery
# 556                       Bistro
# 557       Argentinian Restaurant
# 558           Spanish Restaurant
# 560             Tapas Restaurant
# 561           Spanish Restaurant
# 562                    Gastropub
# 563           Spanish Restaurant
# 564           Spanish Restaurant
# 565          Japanese Restaurant
# 566           Spanish Restaurant
# 567                       Bakery
# 569           Mexican Restaurant
# 570               Breakfast Spot
# 573                        Hotel
# 575                   Restaurant
# 577                   Restaurant
# 578           Spanish Restaurant
# 579       Argentinian Restaurant
# 580          Japanese Restaurant
# 584                        Hotel
# 585           Spanish Restaurant

# %% [markdown]
# * Once the list of Hospitality venues were defined, it was group by District to help to identify which District has more numbers of restaurants, bars, etc.

# %% [markdown]
# * **BARCELONA**

# %%
hospitality_districts_bcn = hospitality_bcn.groupby('District').count()
hospitality_districts_bcn = hospitality_districts_bcn.drop(['District Latitude','District Longitude','Venue Latitude','Venue Longitude','Venue Category'], axis=1)
hospitality_districts_bcn = hospitality_districts_bcn.sort_values(by=['Venue'], ascending=[False])
hospitality_districts_bcn
# Out:
#                      Venue
# District
# Sant Martí              23
# Les Corts               20
# Ciutat Vella            18
# Eixample                18
# Gracia Barcelona        17
# Horta - Guinardó        14
# Sant Andreu             14
# Nou Barris              13
# Sarrià-Sant Gervasi      7
# Sants-Montjuïc           3

# %% [markdown]
# * **MADRID**

# %%
hospitality_districts_mad = hospitality_mad.groupby('District').count()
hospitality_districts_mad = hospitality_districts_mad.drop(['District Latitude','District Longitude','Venue Latitude','Venue Longitude','Venue Category'], axis=1)
hospitality_districts_mad = hospitality_districts_mad.sort_values(by=['Venue'], ascending=[False])
hospitality_districts_mad
# Out:
#                      Venue
# District
# Tetuán Madrid           23
# Hortaleza               22
# Ciudad Lineal           21
# Latina                  21
# Barajas                 21
# San Blas-Canillejas     19
# Salamanca               18
# Carabanchel             17
# Fuencarral-El Pardo     17
# Arganzuela              16
# Retiro Madrid           16
# Vicálvaro               16
# Moncloa-Aravaca         16
# Usera                   13
# Villaverde              13
# Puente de Vallecas      12
# Chamberí                12
# Villa de Vallecas       12
# Moratalaz               10
# Chamartín                3
# Centro                   1

# %% [markdown]
# * Finally, the hospitality venues were grouped by categories to identify which one was more popular among the citizens of each city

# %% [markdown]
# * **BARCELONA**

# %%
hospitality_categories_bcn = hospitality_bcn.groupby('Venue Category').count()
hospitality_categories_bcn = hospitality_categories_bcn.drop(['District','District Latitude','District Longitude','Venue Latitude','Venue Longitude'], axis=1)
hospitality_categories_bcn = hospitality_categories_bcn.sort_values(by=['Venue'], ascending=[False])
hospitality_categories_bcn
# Out:
#                           Venue
# Venue Category
# Restaurant                   16
# Spanish Restaurant           14
# Tapas Restaurant             14
# Mediterranean Restaurant     13
# Hotel                        10
# Bakery                        7
# Pizza Place                   7
# Bar                           6
# Coffee Shop                   5
# Italian Restaurant            5
# Café                          5
# Cocktail Bar                  5
# Argentinian Restaurant        3
# Beer Bar                      3
# Burger Joint                  3
# Food                          2
# Gastropub                     2
# Sushi Restaurant              2
# Sandwich Place                2
# Donut Shop                    2
# Bistro                        2
# Mexican Restaurant            2
# Seafood Restaurant            1
# Polish Restaurant             1
# Taco Place                    1
# Thai Restaurant               1
# Food & Drink Shop             1
# Japanese Restaurant           1
# Ice Cream Shop                1
# German Restaurant             1
# Asian Restaurant              1
# Empanada Restaurant           1
# Diner                         1
# Dessert Shop                  1
# Cupcake Shop                  1
# Chinese Restaurant            1
# Breakfast Spot                1
# Bed & Breakfast               1
# Wine Bar                      1

# %% [markdown]
# * **MADRID**

# %%
hospitality_categories_mad = hospitality_mad.groupby('Venue Category').count()
hospitality_categories_mad = hospitality_categories_mad.drop(['District','District Latitude','District Longitude','Venue Latitude','Venue Longitude'], axis=1)
hospitality_categories_mad = hospitality_categories_mad.sort_values(by=['Venue'], ascending=[False])
hospitality_categories_mad
# Out:
#                              Venue
# Venue Category
# Spanish Restaurant              60
# Restaurant                      21
# Italian Restaurant              17
# Tapas Restaurant                17
# Bar                             16
# Hotel                           16
# Pizza Place                     12
# Café                            12
# Ice Cream Shop                  11
# Coffee Shop                     10
# Bakery                           9
# Argentinian Restaurant           8
# Gastropub                        8
# Chinese Restaurant               6
# Seafood Restaurant               6
# Asian Restaurant                 5
# Mediterranean Restaurant         5
# French Restaurant                4
# Sandwich Place                   4
# Dessert Shop                     4
# Cocktail Bar                     4
# Burger Joint                     4
# Beer Garden                      4
# Diner                            3
# Cupcake Shop                     3
# Fast Food Restaurant             3
# BBQ Joint                        3
# Japanese Restaurant              3
# Paella Restaurant                3
# Mexican Restaurant               3
# Steakhouse                       2
# Sushi Restaurant                 2
# Thai Restaurant                  2
# Peruvian Restaurant              2
# Wine Bar                         2
# Juice Bar                        2
# Beer Bar                         2
# Bistro                           2
# Breakfast Spot                   2
# Eastern European Restaurant      2
# Latin American Restaurant        1
# Donut Shop                       1
# Venezuelan Restaurant            1
# Brazilian Restaurant             1
# Cuban Restaurant                 1
# Soup Place                       1
# Dumpling Restaurant              1
# Korean Restaurant                1
# Polish Restaurant                1
# Food Service                     1
# Indian Restaurant                1
# Persian Restaurant               1
# Pastry Shop                      1
# Middle Eastern Restaurant        1
# Hotel Bar                        1

# %% [markdown]
# ## 4. Results

# %% [markdown]
# ### 4.1. Barcelona

# %% [markdown]
# Barcelona is a Spanish coast city located on the northeastern of the Iberian Peninsula. It has a numerous neighborhoods divided in 10 different Districts: *Ciutat Vella*, *Eixample*, *Sants-Montjuic*, *Les Corts*, *Sarrià-Sant Gervasi*, *Gracia*, *Horta-Guinardo*, *Nou Barris*, *Sant Andreu* and *Sant Marti*.
#
# Running the code described previously helped to discover the following aspect about Barcelona and its Hospitality industry:
#
# * 1. The Foursquare API gave only 30 venues for each district of Barcelona. It means that the **total number of venues** collected for this study was **300**. Even it is a short number, it help to make an idea how important is Hospitality in each district because we compare same number of venues in each district.
#
#
# * 2. After grouped by venue categories, it was easy to identify which ones are related to Hospitality and a list was made with them. As a result, 147 venues were related to **Hospitality represents 49%** of the total of venues of Barcelona.
#
#
# * 3. In terms of **Districts**, the most relevant in the Hospitality industry is ***Sant Martí*** which represent 15.64% of the total of Hospitality venues in Barcelona. Also, this district has 80% of its venues related somehow with Hospitality. To get a general idea, the top 5 districts in this aspect are:
#
#    * *Sant Martí* with 15.64% of Hospitality venues.
#    * *Les Corts* with 13.60% of Hospitality venues.
#    * *Ciutat Vella* with 12.24% of Hospitality venues.
#    * *Eixample* with 12.24% of Hospitality venues.
#    * *Gracia* with 11.56% of Hospitality venues.
#
#
# * 4. About **type of food**, it could say that Barcelona has some preference for the **typical Mediterranean food** as show their preference where *Tapas Restaurant* (9.52%), *Spanish Restaurant* (9.52%) and *Mediterranean Restaurant* (8.84%) are in the top 4 venues category. The top of the list is *Restaurant* (10.84%) which do not determinate the type of any food.

# %% [markdown]
# ### 4.2. Madrid

# %% [markdown]
# Madrid is the most important and populous city of Spain. In fact, it is the capital of this country. It is situated on the center of the Iberian Peninsula. In Madrid exists 131 neighborhoods which are divided into the following 21 districts: *Centro, Arganzuela, Retiro, Salamanca, Chamartin, Tetuan, Chamberi, Fuencarral-El Pardo, Moncloa-Aravaca, Latina, Carabanchel, Usera, Puente de Vallecas, Moratalaz, Ciudad Lineal, Hortaleza, Villaverde, Villa de Vallecas, Vicalvaro, San Blas-Canillejas* and *Barajas*.
#
# As it was done with Barcelona, Madrid has the following specific aspect about Hospitality:
#
# * 1. The Foursquare API gave 30 venues for each district of Madrid but *Centro* and *Chamartin* that only received 7 and 9 venues, respectively. This means that, in this project, Madrid has **589 venues** to analyse.
#
#
# * 2. After grouped by categories, it can be determinated that 319 of the venues are related to Hospitality. It could be interpretated as **Hospitality represents 54.15%** of the total of venues in Madrid.
#
#
# * 3. Analysing by **Districts**, ***Tetuan*** and ***Hortaleza*** are the two more notorious district in terms of Hospitality in Madrid because the first one represents **7.21%**, while *Hortaleza* 6.89%. In fact, 76.67% and 73.33% of their venues are related to Hospitality. Moreover, the top 5 district with more relevance in the Hospitality industry in Madrid are:
#
#     * *Tetuan* with 7.21% of the Hospitality venues.
#     * *Hortaleza* with 6.89% of the Hospitality venues.
#     * *Ciudad Lineal* with 6.58% of the Hospitality venues.
#     * *Latina* with 6.58% of the Hospitality venues.
#     * *Barajas* with 6.58% of the Hospitality venues.
#
#
# * 4. In terms of **type of food**, the most common type of venue is the **Spanish Restaurant** with **18.80%** of the total of Hospitality venues. In addition, the top 5 categories that are more popular in Madrid are:
#
#     * Spanish Restaurant (18.80%)
#     * Restaurant (6.58%)
#     * Italian Restaurant (5.32%)
#     * Tapas Restaurant (5.32%)
#     * Bar (5.01%)

# %% [markdown]
# ## 5. Discussion

# %% [markdown]
# ### 5.1. Results comparation

# %% [markdown]
# As the results show, in terms of Hospitalit venues, Madrid presents a big proportion respect the other type of venues than Barcelona. Also, it can be interpretated as the Hospitality industry represents in Madrid 54.15% of the tertiary sector. While in Barcelona this variable only represents 49%.
#
# An other aspect to be considered is the distribution in the different districts of each city. Barcelona, smaller city than Madrid, has only 10 districts that could explain the distribution among the districts is bigger than Madrid. As it shows, *Sant Marti* has 15.64% of the Hospitality venues of Barcelona, following closely by *Les Corts* and *Ciutat Vella* with 13.60% and 12.24% of the total of these venues, respectively. On the same theme, Madrid presents *Tetuan* and *Hortaleza* as the district with more influence on Hospitality venues with 7.21% and 6.89%.
#
# The last aspect that was considered in this study is the type of food that predominate in each city. It is clearly than in both cities, Spanish restaurants has a big importance. In Madrid, Spanish restaurants is the best option of the citizens because 18.80% of the Hospitality venues were this type. However, Spanish restaurant in Barcelona is not important as Madrid, in fact this type of food is in the second position (9.52%). Barcelona shows a big variety of preference respect type of food, the top five categories are between 8% and 10%.

# %% [markdown]
# ### 5.2. Observations and recommendations

# %% [markdown]
# The main proposal of this project is to determinate how important is Hospitality industry in Madrid and Barcelona. Moreover, it was interested to deep-in the data and analyse with districts has bigger influence on this aspect. However, the analysis was successfull, for future research on this field it could be interesting to determinate how **important is Hospitality industry for each district**. It means, quantify the number of hospitality venues in each district and divide for the total of the district's venues.
#
# Other aspect to consider for future analysis is to try to get in deep and make the same **analysis by neighborhoods** of the city. It would help to get a huge detail of the importance of hospitality industry. Perhaps, using neighborhoods instead districts could give an **increase on the amount of data**. It is know that as big as posssible is the data, better and realistict results can be obtained.
#
# The last recommendation, this project is suitable for any town, city, country or continent. In the future, it could compare more than two cities. For exemple, on next studies it could be compare capital of different European countries as Madrid, Paris, Berlin, Rome or Lisbon.

# %% [markdown]
# ## 6. Conclusion

# %% [markdown]
# The objective of this project is to analyse the importance of the hospitality industry into the two biggest cities of Spain: Barcelona and Madrid.
#
# After define the districts, search for venues and select the relevant data, it can be determinate the following list of conclusions:
#
# * Hospitality industry in Madrid has a bigger impact than in Barcelona. This industry represents 54.15% in Madrid, while in Barcelona is 49%.
#
# * Distribution of the hospitality venues around each city is significantly different. In Barcelona this venues are distributed proportionately among the different districts; in contrast, Madrid shows a desproportionate distribution. An explanation of this effect is that the number of districts of each city is truly different.
#
# * Despite local food is the most predominant type of food in both cities, Barcelona has more influence of the Mediterranean restaurants and Madrid dominate the Spanish restaurants.
#
# Through these conclusions, it can be said that the measures that the Spanish government have token to control the effect of Covid-19 it has affected both cities considerably. However, Madrid has been the worst affected because almost 55% of its economy is derived from the Hospitality industry.
#
# Taking the social aspect in consideration, citizens of both cities prefer to consume local food based on Mediterranean or Spanish diet instead international food as Thai, Japanese or Chinese.
#
# Finally, it is easier to find a place to have a meal in Madrid, if you are in *Tetuan*, *Hortaleza* or *Ciudad Lineal*; but your chances are better if you are in Barcelona and specifically in these districts: *Sant Marti*, *Les Corts* or *Ciutat Vella*.
